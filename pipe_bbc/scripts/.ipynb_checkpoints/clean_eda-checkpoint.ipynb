# %%
import pickle
import time
import pandas as pd
import os
import numpy as np
import json
import re

# %%
with open('../data/bbc_articles_analysis', 'rb') as f:
    articles_analysis=pickle.load(f)

# %%
with open('../data/bbc_twitter_articles_analysis', 'rb') as f:
    twitter_articles_analysis=pickle.load(f)

# %%
articles_analysis.isnull().values.any()
# Out:
# False

# %%
twitter_articles_analysis.isnull().values.any()
# Out:
# True

# %% [markdown]
# # Standardise categories

# %%
# to save memory, new features will be save in a separate dataframe, and merged when required

# %%
article_features_df = pd.DataFrame()

# %%
article_features_df['category']=articles_analysis['category']

# %% [markdown]
# # clean article text and remove quotes

# %%
def tidy_text(x):
    try:
        tidy_list=[]
        x=x.replace('This video can not be played', ' ')
        x=x.split(". ")
        for tn in x:
            tn=tn.strip(' .')
            if tn:
                tidy_list.append(tn)
        end_string =('. ').join(tidy_list) 
    except:
        end_string=x
    return end_string

# %%
def tidy_noquotes(x):
    quote_list=[]
    reg = re.findall(re.escape('"')+"(.*?)"+re.escape('.'), x) 
    for q in reg:
        try:
            if q[0] ==' ':
                continue
            else:
                quote_list.append(q)
        except:
            print('no quote')
    no_q=x
    for sub in quote_list:
        try:
            no_q = no_q.replace(sub, '')
        except:
            print('cannot replace')

    neat_noq_list=[]
    no_q=no_q.split(".")
    for tn in no_q:
        tn=tn.strip('" .')
        if tn:
            neat_noq_list.append(tn)
    end_string =('. ').join(neat_noq_list) 
    return end_string

# %%
article_features_df['clean_text'] = articles_analysis['artText'].apply(tidy_text)

# %%
article_features_df['clean_noquotes'] = article_features_df['clean_text'].apply(tidy_noquotes)
# Out:
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote
# no quote

# %% [markdown]
# # Standardise categories

# %%
cat_dic=articles_analysis['category'].value_counts().to_dict()

# %%
cat_dic
# Out:
# {'Business': 7995,
#  'sport': 6303,
#  'US & Canada': 4893,
#  'Technology': 3724,
#  'blank': 3524,
#  'Entertainment & Arts': 3443,
#  'Europe': 3353,
#  'Science & Environment': 2831,
#  'Middle East': 2020,
#  'Health': 1802,
#  'Asia': 1690,
#  'Magazine': 1595,
#  'Africa': 1465,
#  'UK': 957,
#  'Latin America & Caribbean': 906,
#  'In Pictures': 815,
#  'India': 474,
#  'UK Politics': 423,
#  'China': 323,
#  'US Election 2016': 308,
#  'Trending': 235,
#  'Newsbeat': 193,
#  'World': 167,
#  'Australia': 164,
#  'Stories': 152,
#  'England': 132,
#  'Echo Chambers': 103,
#  'London': 100,
#  'BBC Trending': 96,
#  'Magazine Monitor': 89,
#  'News from Elsewhere': 86,
#  'Scotland': 72,
#  'Northern Ireland': 65,
#  'Education & Family': 55,
#  'EU Referendum': 50,
#  'Scotland politics': 43,
#  'Wales': 41,
#  'Scotland business': 33,
#  'Glasgow & West Scotland': 33,
#  'Edinburgh, Fife & East Scotland': 32,
#  'Manchester': 31,
#  'Leicester': 26,
#  'China blog': 26,
#  'Norfolk': 24,
#  'Birmingham & Black Country': 24,
#  'Family & Education': 21,
#  'Bristol': 20,
#  'Hampshire & Isle of Wight': 20,
#  'Gloucestershire': 19,
#  'NE Scotland, Orkney & Shetland': 19,
#  'Sussex': 17,
#  'Essex': 17,
#  'South East Wales': 16,
#  'Highlands & Islands': 16,
#  'Liverpool': 16,
#  'Election 2015': 15,
#  'World News TV': 14,
#  'South Scotland': 14,
#  'Tyne & Wear': 13,
#  'Cylchgrawn': 12,
#  'Lancashire': 12,
#  'Cambridgeshire': 12,
#  'Beds, Herts & Bucks': 12,
#  'Cornwall': 11,
#  'Derby': 11,
#  'Devon': 11,
#  'Leeds & West Yorkshire': 11,
#  'Tayside and Central Scotland': 10,
#  'Suffolk': 10,
#  'Election 2017': 10,
#  'Kent': 9,
#  'Oxford': 8,
#  'Nottingham': 8,
#  'South West Wales': 7,
#  'Wiltshire': 7,
#  'Coventry & Warwickshire': 7,
#  'Humberside': 7,
#  'Brexit': 6,
#  'Surrey': 6,
#  'Dorset': 6,
#  'Disability': 6,
#  'Northampton': 5,
#  'Somerset': 5,
#  'Ouch': 5,
#  'Explainers': 5,
#  'Tees': 5,
#  'Asia-Pacific': 5,
#  'Stoke & Staffordshire': 4,
#  'Hereford & Worcester': 4,
#  'Sheffield & South Yorkshire': 4,
#  'Mid Wales': 4,
#  'South Asia': 4,
#  'Election 2016': 3,
#  'The Reporters': 3,
#  'Cumbria': 3,
#  'Inside Europe Blog': 3,
#  'York & North Yorkshire': 3,
#  'Berkshire': 3,
#  'Lincolnshire': 2,
#  'Parliaments': 2,
#  'Guernsey': 2,
#  'Wales politics': 2,
#  'North West Wales': 2,
#  'Shropshire': 2,
#  'North East Wales': 2,
#  'Jersey': 2,
#  'New Tech Economy': 1,
#  'The Boss': 1,
#  'Technology of Business': 1,
#  'The Disruptors': 1,
#  'CEO Secrets': 1,
#  'Scotland Election 2016': 1,
#  'Isle Of Man / Ellan Vannin': 1,
#  'World Radio and TV': 1,
#  'US Election 2020': 1,
#  'Reality Check': 1,
#  'Foyle & West': 1,
#  'Global Trade': 1,
#  'The Papers': 1,
#  'Newyddion a mwy': 1,
#  '100 Women': 1,
#  'Crossing Divides': 1,
#  'Global education': 1,
#  'Entrepreneurship': 1,
#  'Eisteddfod Genedlaethol': 1,
#  'N. Ireland Politics': 1}

# %%
cat_dic_rname= {'Business': 'business',
                'sport': 'sport',
                'US & Canada': 'us',
                'Technology': 'tech',
                'blank': 'sport',
                'Entertainment & Arts': 'arts/entertainment',
                'Europe': 'europe',
                'Science & Environment': 'science/environment',
                'Middle East': 'mideast',
                'Health': 'health',
                'Asia': 'asia/pac',
                'Magazine': 'lifestyle/culture',
                'Africa': 'africa',
                'UK': 'uk',
                'Latin America & Caribbean': 'americas',
                'In Pictures': 'pics',
                'India': 'asia/pac',
                'UK Politics': 'politics',
                'China': 'asia/pac',
                'US Election 2016': 'politics',
                'Trending': 'lifestyle/culture',
                'Newsbeat': 'arts/entertainment',
                'World': 'opinion',
                'Australia': 'asia/pac',
                'Stories': 'lifestyle/culture',
                'England': 'uk',
                'Echo Chambers': 'opinion',
                'London': 'uk',
                'BBC Trending': 'opinion',
                'Magazine Monitor': 'offbeat',
                'News from Elsewhere': 'offbeat',
                'Scotland': 'uk',
                'Northern Ireland': 'uk',
                'Education & Family': 'misc',
                'EU Referendum': 'politics',
                'Scotland politics': 'politics',
                'Wales': 'uk',
                'Scotland business': 'business',
                'Glasgow & West Scotland': 'uk',
                'Edinburgh, Fife & East Scotland': 'uk',
                'Manchester': 'uk',
                'Leicester': 'uk',
                'China blog': 'opinion',
                'Norfolk': 'uk',
                'Birmingham & Black Country': 'uk',
                'Family & Education': 'misc',
                'Bristol': 'uk',
                'Hampshire & Isle of Wight': 'uk',
                'Gloucestershire': 'uk',
                'NE Scotland, Orkney & Shetland': 'uk',
                'Sussex': 'uk',
                'Essex': 'uk',
                'South East Wales': 'uk',
                'Highlands & Islands': 'uk',
                'Liverpool': 'uk',
                'Election 2015': 'politics',
                'World News TV': 'lifestyle/culture',
                'South Scotland': 'uk',
                'Tyne & Wear': 'uk',
                'Cylchgrawn': 'uk',
                'Lancashire': 'uk',
                'Cambridgeshire': 'uk',
                'Beds, Herts & Bucks': 'uk',
                'Cornwall': 'uk',
                'Derby': 'uk',
                'Devon': 'uk',
                'Leeds & West Yorkshire': 'uk',
                'Tayside and Central Scotland': 'uk',               
                'Suffolk': 'uk', 
                'Election 2017': 'politics',
                'Kent': 'uk',
                'Oxford': 'uk',
                'Nottingham': 'uk',
                'South West Wales': 'uk',
                'Wiltshire': 'uk',
                'Coventry & Warwickshire': 'uk',
                'Humberside': 'uk',
                'Brexit': 'politics',
                'Surrey': 'uk',
                'Dorset': 'uk',
                'Disability': 'misc',
                'Northampton': 'uk',
                'Somerset': 'uk',
                'Ouch': 'opinion',
                'Explainers': 'opinion',
                'Tees': 'uk',
                'Asia-Pacific': 'asia/pac',
                'Stoke & Staffordshire': 'uk',
                'Hereford & Worcester': 'uk',
                'Sheffield & South Yorkshire': 'uk',
                'Mid Wales': 'uk',
                'South Asia': 'asia/pac',
                'Election 2016': 'politics',
                'The Reporters': 'opinion',
                'Cumbria': 'uk',
                'Inside Europe Blog': 'europe',
                'York & North Yorkshire': 'uk',
                'Berkshire': 'uk',
                'Lincolnshire': 'uk',
                'Parliaments': 'politics',
                'Guernsey': 'uk',
                'Wales politics': 'politics',
                'North West Wales': 'uk',
                'Shropshire': 'uk',
                'North East Wales': 'uk',
                'Jersey': 'uk',
                'New Tech Economy': 'tech',
                'The Boss': 'misc',
                'Scotland Election 2016': 'politics',
                'Isle Of Man / Ellan Vannin': 'uk',
                'World Radio and TV': 'opinion',
                'US Election 2020': 'politics',
                'Foyle & West': 'uk',
                'The Papers': 'politics',
                'Newyddion a mwy': 'wales-uk',
                'Eisteddfod Genedlaethol': 'wales-uk',
                'N. Ireland Politics': 'politics',
                'Crossing Divides': 'misc',
                'Global education': 'misc',
                'Entrepreneurship': 'misc',
                '100 Women': 'misc',
                'Global Trade': 'economy',
                'Reality Check': 'misc',
                'The Disruptors': 'misc',
                'Technology of Business': 'economy',
                'CEO Secrets': 'economy'}

# %%
article_features_df['category_stand']=articles_analysis['category'].apply(lambda x: cat_dic_rname[x])

# %%
article_features_df['outlet']='bbc'

# %%
with open('../data/bbc_articles_features', 'wb') as f:
    pickle.dump(article_features_df, f)

# %%
#wales-uk -- in welsh
#vietnamese sport need deleting

# %%
twitter_articles_analysis['clean']=twitter_articles_analysis['artText'].apply(tidy_text)

# %%
def twitter_cat_stand(x):
    try:
        x=cat_dic_rname[x]
    except:
        x=x
    return x

# %%
twitter_articles_analysis['category']=twitter_articles_analysis['category'].apply(twitter_cat_stand)

# %%
twitter_articles_analysis
# Out:
#                                                       URL            category  \
# 0           http://www.bbc.com/news/world-europe-38442447              europe
# 1               http://www.bbc.com/news/business-40057117            business
# 2             http://www.bbc.com/news/world-asia-24537379            asia/pac
# 3       http://www.bbc.com/news/entertainment-arts-450...  arts/entertainment
# 4                 http://www.bbc.com/news/health-44483080              health
# ...                                                   ...                 ...
# 295807                                                NaN                 NaN
# 295808                                                NaN                 NaN
# 295809                                                NaN                 NaN
# 295810                                                NaN                 NaN
# 295811                                                NaN                 NaN
#
#                                                  headline        date  \
# 0       Berlin truck attack: Polish driver 'shot hours...  2016-12-27
# 1             Call to raise retirement age to at least 70  2017-05-26
# 2       Takashi Yanase, creator of Japan's Anpanman ca...  2013-10-15
# 3               Will Rihanna's eyebrows become the Vogue?  2018-08-01
# 4       Babies most likely to be born at 4am, study finds  2018-06-15
# ...                                                   ...         ...
# 295807                                                NaN  2013-01-01
# 295808                                                NaN  2013-01-01
# 295809                                                NaN  2013-01-01
# 295810                                                NaN  2013-01-01
# 295811                                                NaN  2013-01-01
#
#                                                   artText  \
# 0       Polish driver Lukasz Urban was shot in the hea...
# 1       The retirement age should rise to at least 70 ...
# 2       Japanese cartoonist Takashi Yanase, creator of...
# 3       Long has the thick, full-eyebrowed look reigne...
# 4       Four o'clock in the morning is the time most b...
# ...                                                   ...
# 295807                                                NaN
# 295808                                                NaN
# 295809                                                NaN
# 295810                                                NaN
# 295811                                                NaN
#
#                                                 tweetText  replies  retweets  \
# 0       Berlin truck attack: Polish driver 'shot hours...       11        86
# 1             Call to raise retirement age to at least 70       74        69
# 2       Japanese cartoonist Takashi Yanase, creator of...       16       366
# 3               Will Rihanna's eyebrows become the Vogue?      190        28
# 4       Babies most likely to be born at 4am, study finds       10        16
# ...                                                   ...      ...       ...
# 295807                 Prostate cancer research 'lagging'        2        18
# 295808                   NHS approach to obesity 'patchy'        2         4
# 295809                  Williams in last New Year message        3        15
# 295810                  VIDEO: Edinburgh welcomes in 2013        0        67
# 295811                   Cancer 'changes outlook on life'        8        37
#
#         likes                                              clean
# 0          75  Polish driver Lukasz Urban was shot in the hea...
# 1         104  The retirement age should rise to at least 70 ...
# 2          73  Japanese cartoonist Takashi Yanase, creator of...
# 3         107  Long has the thick, full-eyebrowed look reigne...
# 4          47  Four o'clock in the morning is the time most b...
# ...       ...                                                ...
# 295807      3                                                NaN
# 295808      2                                                NaN
# 295809      4                                                NaN
# 295810     25                                                NaN
# 295811     14                                                NaN
#
# [295812 rows x 10 columns]

# %%
with open('../data/bbc_twitter_articles_analysis', 'wb') as f:
    pickle.dump(twitter_articles_analysis, f)

# %%
af1=article_features_df.to_json()

# %%
with open('../data/bbc_article_features_js', 'w') as f:
    json.dump(af1, f)
